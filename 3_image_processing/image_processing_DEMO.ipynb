# %%
import numpy
import cv2
import image_processor as processor

# %% [markdown]
# # EXAM 3 : IMAGE PROCESSING

# %%
# Example Usage:
image_processor = processor.MyImageProcessor('shapes.jpg')

# %%
print(image_processor.image_path)
# Out:
# shapes.jpg

# %%
print(image_processor.image)
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %% [markdown]
# Manipulate

# %%
import matplotlib.pyplot as plt
plt.imshow(image_processor.image)

# %%
rgb_image = image_processor.bgr_2_rgb_convertor()

# %%
numpy.array_equal(image_processor.image, rgb_image)
# Does not change the original img, creates a new one instead
# Out:
# False

# %%
gray_image = image_processor.bgr_2_gray_scale_convertor()

# %%
image_processor.image.shape
# Out:
# (245, 864, 3)

# %%
resized_image = image_processor._50_percent_resizer()
resized_image.shape
# Out:
# (122, 432, 3)

# %%
plt.imshow(image_processor.image) # original is in bgr
image_processor.image.shape
# Out:
# (245, 864, 3)

# %% [markdown]
# Misc

# %%
# saves imageprocessor.image
image_processor.bgr_image_writer('bgr_image.jpg')
img = cv2.imread('bgr_image.jpg')
plt.imshow(img)
plt.axis('off')
img.shape # Right shape
# Out:
# (245, 864, 3)

# %%
# frame_it
image_with_frame = image_processor.frame_it('output_image_with_frame.jpg')
plt.axis('off')

plt.imshow(image_with_frame)

# %%
# find_center
image_with_center = image_processor.find_center('output_image_with_center.jpg')
plt.axis('off')
plt.imshow(image_with_center)

# %% [markdown]
# Face detection

# %%
image_without_faces, num_faces = image_processor.detect_faces()
plt.imshow(image_without_faces)
plt.axis('off')
plt.show()

print(f"Number of Faces: {num_faces}")
# Out:
# Number of Faces: 0

# %%
face_processor = processor.MyImageProcessor('facedetect.jpg')
image_with_face, num_faces = face_processor.detect_faces()

# %%
plt.imshow(image_with_face)
plt.axis('off')
plt.show()

print(f"Number of Faces: {num_faces}")
# Out:
# Number of Faces: 1
