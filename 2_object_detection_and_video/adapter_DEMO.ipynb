# %%
from media_classifier_adapter import ImageClassification
from media_classifier_adapter import ImageToVideo_ClassificationAdapter
from media_classifier_adapter import VideoClassification
import cv2
import matplotlib.pyplot as plt

# %%
def display(img,cmap=None):
    fig = plt.figure(figsize=(10,8))
    ax = fig.add_subplot(111)
    ax.imshow(img,cmap)

# %%
# image_path = "Object_detection_exam/files/meeting.jpg"
image_path = "meeting.jpg"
image = cv2.imread(image_path)

# Create an instance of ImageClassification
image_classifier = ImageClassification(image_path)

# %%
display(image)

# %%
image_classifier.gather_image_info() # Find objects n store in self.image_info
image_classifier.image_info
# Out:
# [{'class_id': 0,
#   'category': 'Human',
#   'layer_name': 'person',
#   'confidence': 0.993235170841217,
#   'box': (372, 37, 307, 600)},
#  {'class_id': 63,
#   'category': 'In house things',
#   'layer_name': 'laptop',
#   'confidence': 0.9870498180389404,
#   'box': (609, 516, 265, 217)},
#  {'class_id': 0,
#   'category': 'Human',
#   'layer_name': 'person',
#   'confidence': 0.9757108688354492,
#   'box': (655, 50, 294, 607)},
#  {'class_id': 0,
#   'category': 'Human',
#   'layer_name': 'person',
#   'confidence': 0.9558578133583069,
#   'box': (795, 126, 494, 704)},
#  {'class_id': 0,
#   'category': 'Human',
#   'layer_name': 'person',
#   'confidence': 0.9199008345603943,
#   'box': (-2, 194, 467, 627)},
#  {'class_id': 27,
#   'category': 'Sport and Lifestyle',
#   'layer_name': 'tie',
#   'confidence': 0.9151584506034851,
#   'box': (218, 421, 43, 152)}]

# %%
boxed_image = image_classifier.draw_boxes_on_image() # Createbox img
image_classifier.display_image(boxed_image)

# %%
# Vid path
video_path = "short_yoga.mp4"

# Create an instance of ImageClassification to be used by VideoClassification
image_classifier = ImageClassification(video_path)
adapter = ImageToVideo_ClassificationAdapter(video_path,image_classifier)

# %%
frames = adapter.get_all_frames_from_vid()
len(frames),type(frames[0])
# Out:
# (63, numpy.ndarray)

# %%
adapter.gather_video_info(frames) # Get info on all obj for all frames
# Out:
# Processing 1/63 frames.
# Processing 2/63 frames.
# Processing 3/63 frames.
# Processing 4/63 frames.
# Processing 5/63 frames.
# Processing 6/63 frames.
# Processing 7/63 frames.
# Processing 8/63 frames.
# Processing 9/63 frames.
# Processing 10/63 frames.
# Processing 11/63 frames.
# Processing 12/63 frames.
# Processing 13/63 frames.
# Processing 14/63 frames.
# Processing 15/63 frames.
# Processing 16/63 frames.
# Processing 17/63 frames.
# Processing 18/63 frames.
# Processing 19/63 frames.
# Processing 20/63 frames.
# Processing 21/63 frames.
# Processing 22/63 frames.
# Processing 23/63 frames.
# Processing 24/63 frames.
# Processing 25/63 frames.
# Processing 26/63 frames.
# Processing 27/63 frames.
# Processing 28/63 frames.
# Processing 29/63 frames.
# Processing 30/63 frames.
# Processing 31/63 frames.
# Processing 32/63 frames.
# Processing 33/63 frames.
# Processing 34/63 frames.
# Processing 35/63 frames.
# Processing 36/63 frames.
# Processing 37/63 frames.
# Processing 38/63 frames.
# Processing 39/63 frames.
# Processing 40/63 frames.
# Processing 41/63 frames.
# Processing 42/63 frames.
# Processing 43/63 frames.
# Processing 44/63 frames.
# Processing 45/63 frames.
# Processing 46/63 frames.
# Processing 47/63 frames.
# Processing 48/63 frames.
# Processing 49/63 frames.
# Processing 50/63 frames.
# Processing 51/63 frames.
# Processing 52/63 frames.
# Processing 53/63 frames.
# Processing 54/63 frames.
# Processing 55/63 frames.
# Processing 56/63 frames.
# Processing 57/63 frames.
# Processing 58/63 frames.
# Processing 59/63 frames.
# Processing 60/63 frames.
# Processing 61/63 frames.
# Processing 62/63 frames.
# Processing 63/63 frames.

# %%
adapter.all_frame_obj_info
# Out:
# {'Frame 0': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9728789329528809,
#    'box': (59, 140, 173, 241)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.97162926197052,
#    'box': (358, 162, 103, 181)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9412072896957397,
#    'box': (227, 83, 240, 391)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9267191290855408,
#    'box': (611, 129, 203, 275)}],
#  'Frame 1': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9735540747642517,
#    'box': (358, 162, 103, 181)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9724944233894348,
#    'box': (60, 140, 172, 241)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9408097267150879,
#    'box': (226, 83, 241, 391)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.924363911151886,
#    'box': (613, 129, 199, 274)}],
#  'Frame 2': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9751764535903931,
#    'box': (59, 140, 171, 241)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9681816101074219,
#    'box': (358, 161, 104, 182)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9519044756889343,
#    'box': (228, 84, 239, 390)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.912823498249054,
#    'box': (615, 128, 194, 276)}],
#  'Frame 3': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9781858921051025,
#    'box': (60, 141, 171, 241)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9693961143493652,
#    'box': (357, 162, 105, 181)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9555091261863708,
#    'box': (226, 84, 241, 389)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9106892943382263,
#    'box': (618, 127, 188, 277)}],
#  'Frame 4': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9816529750823975,
#    'box': (60, 141, 170, 242)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9689640998840332,
#    'box': (357, 162, 105, 181)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9583841562271118,
#    'box': (227, 85, 240, 388)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9061172604560852,
#    'box': (620, 126, 184, 277)}],
#  'Frame 5': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9777420163154602,
#    'box': (59, 142, 172, 241)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9704748392105103,
#    'box': (358, 163, 104, 180)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9508119225502014,
#    'box': (223, 86, 244, 388)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9123424291610718,
#    'box': (621, 126, 179, 278)}],
#  'Frame 6': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9806597232818604,
#    'box': (59, 145, 171, 238)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.970166802406311,
#    'box': (357, 164, 105, 179)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9591045379638672,
#    'box': (226, 87, 240, 386)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9114399552345276,
#    'box': (618, 127, 185, 277)}],
#  'Frame 7': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9807285070419312,
#    'box': (59, 145, 172, 238)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.971362829208374,
#    'box': (357, 164, 105, 179)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9570086598396301,
#    'box': (225, 87, 241, 386)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9105259776115417,
#    'box': (618, 127, 185, 277)}],
#  'Frame 8': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9786185622215271,
#    'box': (60, 145, 170, 237)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9648852944374084,
#    'box': (356, 165, 105, 178)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.956017255783081,
#    'box': (225, 87, 242, 385)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9138352870941162,
#    'box': (615, 127, 191, 277)}],
#  'Frame 9': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9796740412712097,
#    'box': (60, 145, 170, 238)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9580283761024475,
#    'box': (356, 165, 106, 177)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9562225341796875,
#    'box': (225, 87, 242, 385)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9158926010131836,
#    'box': (616, 127, 187, 277)}],
#  'Frame 10': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9809764623641968,
#    'box': (60, 145, 170, 238)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9651908874511719,
#    'box': (227, 88, 240, 385)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9572649002075195,
#    'box': (357, 165, 105, 178)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9282814860343933,
#    'box': (614, 128, 193, 277)}],
#  'Frame 11': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9807931780815125,
#    'box': (60, 145, 170, 237)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9638230800628662,
#    'box': (224, 88, 244, 384)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9588838219642639,
#    'box': (357, 164, 105, 180)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9326783418655396,
#    'box': (615, 128, 191, 278)}],
#  'Frame 12': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9815744757652283,
#    'box': (59, 145, 170, 237)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9649325013160706,
#    'box': (222, 89, 247, 384)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9580899477005005,
#    'box': (358, 165, 104, 180)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9412139058113098,
#    'box': (614, 128, 192, 277)}],
#  'Frame 13': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9836977124214172,
#    'box': (59, 145, 170, 237)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9622527956962585,
#    'box': (223, 89, 246, 383)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9590764045715332,
#    'box': (358, 165, 104, 180)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9418238401412964,
#    'box': (612, 128, 195, 277)}],
#  'Frame 14': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9805704355239868,
#    'box': (59, 145, 170, 237)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9554029107093811,
#    'box': (357, 164, 104, 180)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9503430724143982,
#    'box': (222, 88, 246, 386)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9388341307640076,
#    'box': (613, 129, 194, 276)}],
#  'Frame 15': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9784533381462097,
#    'box': (59, 145, 170, 238)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9605883359909058,
#    'box': (223, 88, 244, 386)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9538708329200745,
#    'box': (356, 164, 105, 179)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9351674318313599,
#    'box': (614, 129, 189, 276)}],
#  'Frame 16': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9765823483467102,
#    'box': (58, 145, 171, 238)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9600533843040466,
#    'box': (225, 88, 242, 386)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9467023015022278,
#    'box': (355, 164, 105, 179)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9308205842971802,
#    'box': (616, 129, 186, 276)}],
#  'Frame 17': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9764567613601685,
#    'box': (59, 144, 170, 240)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9515537023544312,
#    'box': (226, 88, 241, 385)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9401569962501526,
#    'box': (355, 164, 105, 179)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9190424084663391,
#    'box': (617, 129, 180, 276)}],
#  'Frame 18': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9778645634651184,
#    'box': (59, 144, 169, 239)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9552533030509949,
#    'box': (226, 87, 240, 386)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9518342614173889,
#    'box': (355, 164, 105, 179)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.921360969543457,
#    'box': (613, 128, 187, 276)}],
#  'Frame 19': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9776026010513306,
#    'box': (59, 144, 169, 239)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9543243646621704,
#    'box': (226, 87, 240, 386)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9514355063438416,
#    'box': (355, 165, 105, 178)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9207630753517151,
#    'box': (614, 128, 188, 276)}],
#  'Frame 20': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9755060076713562,
#    'box': (59, 143, 169, 241)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9550577402114868,
#    'box': (227, 87, 240, 385)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9433405995368958,
#    'box': (355, 163, 105, 179)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.936032235622406,
#    'box': (610, 128, 199, 275)}],
#  'Frame 21': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9762449264526367,
#    'box': (59, 144, 169, 239)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9574096202850342,
#    'box': (225, 86, 242, 388)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9526784420013428,
#    'box': (356, 163, 104, 179)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9257463812828064,
#    'box': (613, 128, 191, 276)}],
#  'Frame 22': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9772025942802429,
#    'box': (59, 144, 170, 240)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9629824161529541,
#    'box': (226, 86, 239, 387)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.950522243976593,
#    'box': (355, 164, 105, 178)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9393131732940674,
#    'box': (611, 127, 197, 275)}],
#  'Frame 23': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9742798805236816,
#    'box': (60, 143, 168, 241)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9671030640602112,
#    'box': (227, 84, 240, 390)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9435522556304932,
#    'box': (355, 163, 105, 179)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9317800402641296,
#    'box': (615, 127, 190, 275)}],
#  'Frame 24': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9740206003189087,
#    'box': (60, 143, 168, 240)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9673122763633728,
#    'box': (226, 84, 239, 390)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9499568343162537,
#    'box': (356, 163, 104, 180)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9359818696975708,
#    'box': (617, 126, 186, 275)}],
#  'Frame 25': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.974385678768158,
#    'box': (60, 143, 168, 240)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9672083854675293,
#    'box': (228, 84, 238, 390)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9480304718017578,
#    'box': (356, 163, 104, 180)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9362733960151672,
#    'box': (617, 126, 186, 275)}],
#  'Frame 26': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9767721891403198,
#    'box': (60, 143, 168, 240)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.955980122089386,
#    'box': (226, 84, 240, 390)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.952533483505249,
#    'box': (356, 163, 104, 180)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9325312376022339,
#    'box': (617, 126, 184, 275)}],
#  'Frame 27': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9781134128570557,
#    'box': (60, 142, 167, 240)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9653083086013794,
#    'box': (225, 84, 242, 391)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9521456956863403,
#    'box': (355, 163, 104, 180)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9291580319404602,
#    'box': (617, 127, 182, 274)}],
#  'Frame 28': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9752772450447083,
#    'box': (61, 141, 166, 241)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9620041847229004,
#    'box': (226, 83, 242, 392)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9482110738754272,
#    'box': (355, 163, 104, 180)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9351688027381897,
#    'box': (613, 125, 193, 275)}],
#  'Frame 29': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9787867069244385,
#    'box': (61, 141, 166, 242)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9660448431968689,
#    'box': (227, 83, 240, 391)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9377737641334534,
#    'box': (355, 162, 104, 180)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9272865653038025,
#    'box': (615, 127, 189, 274)}],
#  'Frame 30': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9800023436546326,
#    'box': (60, 140, 167, 243)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.966928243637085,
#    'box': (228, 83, 238, 392)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9272537231445312,
#    'box': (354, 161, 105, 180)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9229699969291687,
#    'box': (619, 126, 180, 275)}],
#  'Frame 31': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9802066087722778,
#    'box': (61, 140, 166, 243)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9674079418182373,
#    'box': (228, 83, 238, 392)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9257704019546509,
#    'box': (354, 161, 105, 180)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9221989512443542,
#    'box': (619, 126, 180, 276)}],
#  'Frame 32': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9786425828933716,
#    'box': (60, 140, 166, 243)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9684078097343445,
#    'box': (230, 82, 233, 393)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.936388373374939,
#    'box': (616, 126, 185, 276)}],
#  'Frame 33': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9713793396949768,
#    'box': (60, 139, 165, 243)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9703893065452576,
#    'box': (229, 82, 233, 394)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9387596845626831,
#    'box': (614, 125, 191, 277)}],
#  'Frame 34': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9709959030151367,
#    'box': (226, 80, 236, 395)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9701991081237793,
#    'box': (59, 139, 166, 243)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9350072145462036,
#    'box': (612, 124, 191, 278)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9017313122749329,
#    'box': (353, 162, 105, 178)}],
#  'Frame 35': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9713042378425598,
#    'box': (224, 80, 237, 396)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9708014130592346,
#    'box': (58, 140, 167, 242)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9245953559875488,
#    'box': (609, 123, 193, 278)}],
#  'Frame 36': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9721924066543579,
#    'box': (57, 140, 168, 242)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9709799289703369,
#    'box': (223, 80, 239, 395)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9342522621154785,
#    'box': (611, 124, 194, 276)}],
#  'Frame 37': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9708690047264099,
#    'box': (57, 140, 168, 242)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9707023501396179,
#    'box': (223, 80, 239, 395)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9344472289085388,
#    'box': (611, 124, 193, 276)}],
#  'Frame 38': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9708276391029358,
#    'box': (57, 140, 167, 241)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9678823351860046,
#    'box': (223, 81, 241, 394)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9246770739555359,
#    'box': (608, 123, 200, 275)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9016255140304565,
#    'box': (352, 160, 106, 179)}],
#  'Frame 39': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9717993140220642,
#    'box': (223, 81, 241, 394)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9698739647865295,
#    'box': (57, 141, 166, 240)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9176024794578552,
#    'box': (608, 125, 198, 269)}],
#  'Frame 40': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9711194634437561,
#    'box': (226, 81, 238, 393)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9697960019111633,
#    'box': (56, 141, 167, 240)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9166228771209717,
#    'box': (610, 124, 197, 272)}],
#  'Frame 41': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9677467942237854,
#    'box': (56, 139, 167, 242)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9667345881462097,
#    'box': (224, 80, 239, 394)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9030805826187134,
#    'box': (610, 123, 191, 274)}],
#  'Frame 42': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9680238962173462,
#    'box': (221, 79, 243, 394)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9657936692237854,
#    'box': (55, 139, 167, 242)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9279415607452393,
#    'box': (605, 123, 203, 273)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9041306376457214,
#    'box': (349, 159, 108, 180)}],
#  'Frame 43': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9673457741737366,
#    'box': (221, 79, 243, 393)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.965883195400238,
#    'box': (55, 139, 167, 242)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.929966926574707,
#    'box': (605, 123, 204, 273)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9046385288238525,
#    'box': (349, 159, 108, 180)}],
#  'Frame 44': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9664236307144165,
#    'box': (219, 79, 245, 394)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9658649563789368,
#    'box': (56, 139, 167, 241)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9309111833572388,
#    'box': (599, 121, 214, 268)}],
#  'Frame 45': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9690266847610474,
#    'box': (219, 78, 245, 395)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.967173159122467,
#    'box': (54, 140, 167, 240)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.927042543888092,
#    'box': (601, 120, 210, 269)}],
#  'Frame 46': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9717123508453369,
#    'box': (219, 77, 245, 395)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9675805568695068,
#    'box': (54, 140, 167, 240)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.916848361492157,
#    'box': (605, 123, 204, 274)}],
#  'Frame 47': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9709566831588745,
#    'box': (220, 79, 244, 392)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9617412090301514,
#    'box': (54, 139, 167, 240)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9033306241035461,
#    'box': (605, 122, 201, 274)}],
#  'Frame 48': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9719238877296448,
#    'box': (216, 77, 248, 394)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9574398994445801,
#    'box': (55, 134, 170, 242)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9170148372650146,
#    'box': (604, 123, 204, 274)}],
#  'Frame 49': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9719365835189819,
#    'box': (214, 76, 249, 395)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9583064913749695,
#    'box': (55, 134, 170, 242)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9160186648368835,
#    'box': (604, 122, 203, 275)}],
#  'Frame 50': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9731245636940002,
#    'box': (213, 76, 249, 394)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9574480652809143,
#    'box': (56, 134, 168, 242)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.913560688495636,
#    'box': (603, 124, 204, 271)}],
#  'Frame 51': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9700905680656433,
#    'box': (211, 73, 253, 397)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9651687145233154,
#    'box': (55, 133, 169, 243)}],
#  'Frame 52': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9710642099380493,
#    'box': (208, 74, 257, 397)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9678593873977661,
#    'box': (55, 132, 170, 244)}],
#  'Frame 53': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9760710000991821,
#    'box': (209, 74, 256, 397)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9699046611785889,
#    'box': (54, 132, 171, 244)}],
#  'Frame 54': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9764505624771118,
#    'box': (209, 77, 253, 391)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9691751003265381,
#    'box': (52, 132, 173, 243)}],
#  'Frame 55': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9756652116775513,
#    'box': (208, 75, 256, 395)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9691120386123657,
#    'box': (52, 133, 173, 242)}],
#  'Frame 56': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9775546789169312,
#    'box': (209, 79, 254, 390)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9645034670829773,
#    'box': (52, 133, 173, 243)}],
#  'Frame 57': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9763560891151428,
#    'box': (209, 79, 254, 390)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9614007472991943,
#    'box': (54, 134, 170, 242)}],
#  'Frame 58': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.977686882019043,
#    'box': (209, 80, 253, 388)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9626528024673462,
#    'box': (54, 134, 170, 241)}],
#  'Frame 59': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9763360619544983,
#    'box': (207, 79, 255, 389)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9633652567863464,
#    'box': (54, 134, 170, 241)}],
#  'Frame 60': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9703696370124817,
#    'box': (207, 78, 256, 390)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.963597297668457,
#    'box': (51, 135, 173, 240)}],
#  'Frame 61': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9702181816101074,
#    'box': (207, 79, 256, 390)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9635478258132935,
#    'box': (51, 135, 173, 240)}],
#  'Frame 62': [{'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9694712162017822,
#    'box': (207, 78, 255, 389)},
#   {'class_id': 0,
#    'category': 'Human',
#    'layer_name': 'person',
#    'confidence': 0.9612874388694763,
#    'box': (50, 134, 174, 241)}]}

# %%
adapter.all_frame_obj_info['Frame 1']
# Out:
# [{'class_id': 0,
#   'category': 'Human',
#   'layer_name': 'person',
#   'confidence': 0.9735540747642517,
#   'box': (358, 162, 103, 181)},
#  {'class_id': 0,
#   'category': 'Human',
#   'layer_name': 'person',
#   'confidence': 0.9724944233894348,
#   'box': (60, 140, 172, 241)},
#  {'class_id': 0,
#   'category': 'Human',
#   'layer_name': 'person',
#   'confidence': 0.9408097267150879,
#   'box': (226, 83, 241, 391)},
#  {'class_id': 0,
#   'category': 'Human',
#   'layer_name': 'person',
#   'confidence': 0.924363911151886,
#   'box': (613, 129, 199, 274)}]

# %%
video_classifier = VideoClassification(video_path, image_classifier)

# %%
box_frames = video_classifier.box_video_frames(frames)

# %%
image_classifier.display_image(box_frames[0])

# %%
video_classifier.display_video_frames(box_frames,save_video=True,video_name='boxed_video_yoga.mp4')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 video_classifier.display_video_frames(box_frames,save_video=True,video_name='boxed_video_yoga.mp4')
#
# File c:\Users\tyraf\Documents\GIT_repos\Object_detection_exam\2_object_detection_and_video\media_classifier_adapter.py:346, in VideoClassification.display_video_frames(self, frames, video_name, frame_rate, save_video)
#     344 height, width, _ = frames[0].shape # Create a video with size of the frames
#     345 fourcc = cv2.VideoWriter_fourcc(*'XVID')
# --> 346 out = cv2.VideoWriter(output_file, fourcc, frame_rate, (width, height))
#     348 for frame in frames:
#     349     if frame is not None:
#
# NameError: name 'output_file' is not defined
